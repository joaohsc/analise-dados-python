# %%
import pandas as pd

# %%
data_path = "data/dados_importacao.xlsx"

data_df = pd.read_excel(data_path)

display(data_df)
# Out:
#         Nome/Razão Social Nome Fantasia        CPF/CNPJ Data Nasc.  \
# 0            Nicolas Melo           NaN  591.267.843-19 1982-03-16
# 1           Igor Silveira           NaN  102.694.758-85 1975-04-26
# 2         Henrique da Luz           NaN  782.531.904-41 1997-06-17
# 3       Valentina da Mota           NaN  865.902.374-92        NaT
# 4     Giovanna Cavalcanti           NaN  173.598.642-91 1964-11-30
# ...                   ...           ...             ...        ...
# 1195     Agatha das Neves           NaN  862.749.031-78 1968-08-30
# 1196  Sr. Eduardo Rezende           NaN  935.082.416-70        NaT
# 1197         Pedro Vieira           NaN  023.596.147-70        NaT
# 1198      Lorena da Rocha           NaN  163.542.790-80 2000-06-23
# 1199          Maria Pires           NaN  083.456.921-33        NaT
#
#      Data Cadastro cliente     Celulares     Telefones  \
# 0               2023-01-02           NaN  5.581004e+12
# ...

# %%
# data_df.sort_values(['Nome/Razão Social'])
duplicados_df = data_df[data_df.duplicated(subset=['CPF/CNPJ'], keep="last")]

data_df_tratado = data_df.drop(index=duplicados_df.index.tolist())

# %%
planos_df=
